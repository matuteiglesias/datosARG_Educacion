# %%
import pandas as pd

sedes = pd.read_csv('./sedes_2.csv')
sedes['Direcci\xc3\xb3n'] = sedes['Direcci\xc3\xb3n'].str[12:]
sedes['Nombre'] = sedes['Universidad'] +', '+sedes['Facultad'] 

oferta = pd.read_csv('./oferta.csv')

# %%
ambito = pd.read_csv('./oferta_ambito.csv')
provincia = pd.read_csv('./oferta_provincia.csv')
disciplina = pd.read_csv('./oferta_disciplina.csv')

# %%
disciplina.merge(provincia).merge(ambito, how = 'left').sample(10)
# Out:
#                                       Universidad  \
# 5832           Universidad Nacional de Río Cuarto
# 158                      Universidad del Salvador
# 3952           Universidad Autónoma de Entre Ríos
# 3970                 Universidad Católica de Cuyo
# 6246             Universidad Católica de Santa Fe
# 2004              Universidad Nacional de Córdoba
# 6108  Universidad Católica de Santiago del Estero
# 3650              Universidad Nacional de Rosario
# 5734              Universidad Nacional de Córdoba
# 3392                    Universidad del Aconcagua
#
#                                                Facultad  \
# 5832                       Facultad de Ciencias Humanas
# 158           Facultad de Historia, Geografía y Turismo
# 3952      Facultad de Ciencia y Tecnología. Sede Crespo
# 3970  Facultad Don Bosco de Enología y Ciencias de l...
# 6246                            Facultad de Humanidades
# 2004                      Facultad de Ciencias Sociales
# 6108                    Facultad de Ciencias Económicas
# 3650  Facultad de Ciencia Política y Relaciones Inte...
# 5734  Facultad de Ciencias Médicas - Escuela de Enfe...
# 3392                       Facultad de Ciencias Médicas
#
#                                                  Título  \
# 5832                           Licenciado en Enfermería
# 158                               Licenciado en Turismo
# 3952   Técnico Universitario en Planeamiento Industrial
# 3970  Licenciado en Enología e Industria Frutihortícola
# 6246  Licenciado en Ciencias Sociales - Ciclo de Lic...
# 2004                     Licenciado en Ciencia Política
# 6108  Técnico Universitario en Gestión de Recursos H...
# 3650  Bachiller Universitario -título intermedio de ...
# 5734   Licenciado en Enfermería - Ciclo de Licenciatura
# 3392  Licenciado en Educación Física - Ciclo de Comp...
#
#                            Tipo de Título     Duración  \
# 5832                                Grado       5 Años
# 158                                 Grado       4 Años
# 3952                 Técnico Instrumental       3 Años
# 3970                                Grado       5 Años
# 6246                Ciclo de Licenciatura     1.5 Años
# 2004                                Grado       5 Años
# 6108                      Otros Pregrados       3 Años
# 3650                    Título Intermedio       2 Años
# 5734                Ciclo de Licenciatura  5 Semestres
# 3392  Ciclo de Complementación Curricular       2 Años
#
#                                  Condiciones de Ingreso  \
# 5832  Asistencia y Aprobación a Curso de Ingreso o N...
# 158                         Consulte con la Institución
# 3952         Asistencia a Curso de Ingreso o Nivelación
# 3970  Asistencia y Aprobación a Curso de Ingreso o N...
# 3952                       Entre Ríos  Público
# 3970                          Mendoza  Privado
# 6246                         Santa Fé  Privado
# 2004                         Córodoba  Público
# 6108              Santiago del Estero  Privado
# 3650                         Santa Fé  Público
# 5734                         Córodoba  Público
# 3392                          Mendoza  Privado

# %%
import json
import time
import urllib
import urllib2

def geolocate_rest_api(searchtext, APP_ID = None, APP_CODE = None, BACKOFF_TIME = 30):

    base_url = 'https://geocoder.api.here.com/6.2/geocode.json'

    # This joins the parts of the URL together into one string.
    url = base_url + '?' + urllib.urlencode({
        'searchtext': "%s" % (searchtext),
        'app_id': APP_ID,
        'app_code': APP_CODE,
    })
#     print url
    response = str(urllib2.urlopen(url).read())
    result = json.loads(response.replace('\\n', ''))
    return result


def set_geolocation_values(df):
    if result['Response']['View'] != []:
        core_result = result['Response']['View'][0]['Result'][0]['Location']
        pos = core_result['NavigationPosition']
        address = core_result['Address']

        if 'Country' in address.keys(): df.set_value(i,'Pais', address[u'Country'])
        if 'State' in address.keys(): df.set_value(i,'Provincia', address[u'State'])
        if 'County' in address.keys(): df.set_value(i,'Municipio', address[u'County'])
#         if 'Label' in address.keys(): df.set_value(i,'Direccion', address[u'Label'])
    #     df.set_value(i,'location_id', address[u'LocationId'])
        if 'Longitude' in pos[0].keys(): df.set_value(i,'lng', pos[0]['Longitude'])
        if 'Latitude' in pos[0].keys(): df.set_value(i,'lat', pos[0]['Latitude'])
    else:
        pass

# %%
dataframe = sedes[['Dirección']].drop_duplicates()

col = 'Dirección'
APP_ID = 'YpwwDaCIpYuxqHCMBAZY'
APP_CODE = 'aI2CPGUAgGi_DwMsTXQK2Q'

for i, row in dataframe.iterrows():
    result = geolocate_rest_api(row[col], APP_ID, APP_CODE)
#     print row[col]
    
    if result:
        set_geolocation_values(dataframe)

    if i%10 == 0:
        print 'processed row '+str(i)
# Out:
# processed row 0
# processed row 30
# processed row 40
# processed row 50
# processed row 60
# processed row 70
# processed row 120
# processed row 130
# processed row 170
# processed row 190
# processed row 200
# processed row 220
# processed row 230
# processed row 240
# processed row 260
# processed row 280
# processed row 290
# processed row 300
# processed row 310
# processed row 320
# processed row 330
# /home/miglesia/anaconda2/lib/python2.7/site-packages/IPython/kernel/__main__.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/miglesia/anaconda2/lib/python2.7/site-packages/IPython/kernel/__main__.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/miglesia/anaconda2/lib/python2.7/site-packages/IPython/kernel/__main__.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/miglesia/anaconda2/lib/python2.7/site-packages/IPython/kernel/__main__.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/miglesia/anaconda2/lib/python2.7/site-packages/IPython/kernel/__main__.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
df = sedes.merge(dataframe, how = 'left')
df.to_csv('sedes_geoloc.csv', encoding = 'utf-8')
