# %%
import pandas as pd
pd.options.display.max_columns = 99
import numpy as np

# %%
df_list = []
for regimen in ['1', '2']:

    df1 = pd.read_csv('./anuario_2013/clean/cuadro_2.'+regimen+'.10.csv', header = [0, 1, 2], index_col=0, thousands='.')
    df2 = pd.read_csv('./anuario_2013/clean/cuadro_2.'+regimen+'.11.csv', header = [0, 1, 2], index_col=0, thousands='.')
    df3 = pd.read_csv('./anuario_2013/clean/cuadro_2.'+regimen+'.12.csv', header = [0, 1, 2], index_col=0, thousands='.')
    df4 = pd.read_csv('./anuario_2013/clean/cuadro_2.'+regimen+'.13.csv', header = [0, 1, 2], index_col=0, thousands='.')
    df5 = pd.read_csv('./anuario_2013/clean/cuadro_2.'+regimen+'.14.csv', header = [0, 1, 2], index_col=0, thousands='.')

    # Concatenarlos (ubicarlos uno tras otro horizontalmente)
    df = pd.concat([df1, df2, df3, df5], axis = 1, sort = False)

    # Remover filas de totales
    df = df.loc[[i for i in df.index if 'Total' not in i]]
    df_list += [df]
    
df_ = pd.concat(df_list)
ests_disc = df_['Disciplina']

# %%
### Carreras elegidas en CABA vs GBA-La Plata vs interior Buenos Aires
inst = pd.read_csv('./instituciones.csv', encoding = 'latin')

inst_CABA = inst.loc[inst['Provincia'] == 'CABA']
inst_GBA = inst.loc[(inst['Provincia'] == 'Buenos Aires') & (inst['Región'] == 'Metropolitana')]
inst_PBA = inst.loc[inst['Región'] == 'Bonaerense']

# %%
pd.concat([inst_GBA.set_index('Institución')[['Régimen']], ests_disc], axis = 1)
# Out:
# /home/miglesia/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                   Régimen  (Arquitectura y Diseño, EGRE)  \
# Abierta Interamericana                NaN                          182.0
# Aconcagua                             NaN                            2.0
# Adventista del Plata                  NaN                            NaN
# Aeronáutico                           NaN                            NaN
# Argentina John F. Kennedy             NaN                            5.0
# Argentina de la Empresa               NaN                          180.0
# Arturo Jauretche                  Estatal                            NaN
# Atlántida Argentina                   NaN                            NaN
# Austral                           Privado                            NaN
# Autónoma de Entre Ríos                NaN                            NaN
# Avellaneda                        Estatal                            0.0
# Belgrano                              NaN                           49.0
# Blas Pascal                           NaN                           62.0
# Buenos Aires                          NaN                         1820.0
# CAECE                                 NaN                           10.0
# CEMA                                  NaN                            NaN
# CEMIC                                 NaN                            NaN
# Catamarca                             NaN                            NaN
# Católica Argentina                    NaN                            NaN
# Católica de Cuyo                      NaN                            NaN
# Católica de Córdoba                   NaN                           66.0
# Católica de La Plata              Privado                           16.0
# Católica de Salta                     NaN                           53.0
# Católica de Santa Fe                  NaN                           46.0
# Católica de Santiago del Estero       NaN                           21.0
# Centro Educativo Latinoamericano      NaN                            NaN
# Centro de la PBA                      NaN                            NaN
# Chaco Austral                         NaN                            NaN
# Champagnat                            NaN                            7.0
# Chilecito                             NaN                            NaN
# ...                                   ...                            ...
# Oeste                             Estatal                            NaN
# Palermo                               NaN                          546.0
# Patagonia Austral                     NaN                            NaN
# Patagonia S. J. Bosco                 NaN                            NaN
# Policía Federal Argentina             NaN                            NaN
# Quilmes                           Estatal                            7.0
# River Plate                           NaN                            NaN
# Rosario                               NaN                          407.0
# Río Cuarto                            NaN                            NaN
# Río Negro                             NaN                           12.0
# Salta                                 NaN                            NaN
# Salvador                              NaN                           16.0
# San Andrés                            NaN                            NaN
# San Andés                             NaN                            NaN
# San Isidro                        Privado                            NaN
# San Juan                              NaN                           96.0
# San Luis                              NaN                            NaN
# San Martín                        Estatal                            NaN
# San Pablo  T                          NaN                            NaN
# San Pablo T                           NaN                           13.0
# Santiago del Estero                   NaN                            NaN
# Seguridad Marítima                    NaN                            NaN
# Sur                                   NaN                            NaN
# Tecnológica Nacional                  NaN                            1.0
# Tierra del Fuego                      NaN                            NaN
# Torcuato Di Tella                     NaN                           17.0
# Tres de Febrero                   Estatal                            NaN
# Tucumán                               NaN                          164.0
# Villa María                           NaN                            6.0
# Villa Mercedes                        NaN                            NaN
#
#                                   (Arquitectura y Diseño, EST)  \
# Abierta Interamericana                                  1056.0
# Aconcagua                                                 49.0
# Adventista del Plata                                       NaN
# Aeronáutico                                                NaN
# Argentina John F. Kennedy                                303.0
# Argentina de la Empresa                                 2012.0
# Arturo Jauretche                                           NaN
# Atlántida Argentina                                        NaN
# Austral                                                    NaN
# Autónoma de Entre Ríos                                     NaN
# Avellaneda                                                83.0
# Belgrano                                                1960.0
# Blas Pascal                                              438.0
# Buenos Aires                                           42990.0
# CAECE                                                    190.0
# CEMA                                                       NaN
# CEMIC                                                      NaN
# Catamarca                                                  NaN
# Católica Argentina                                         NaN
# Católica de Cuyo                                           NaN
# Católica de Córdoba                                      534.0
# Católica de La Plata                                     502.0
# Católica de Salta                                       1012.0
# Católica de Santa Fe                                     888.0
# Católica de Santiago del Estero                           97.0
# Centro Educativo Latinoamericano                           NaN
# Centro de la PBA                                           NaN
# Chaco Austral                                              NaN
# Champagnat                                               132.0
# Chilecito                                                  NaN
# ...                                                        ...
# Oeste                                                      NaN
# Palermo                                                 5122.0
# Patagonia Austral                                          NaN
# Patagonia S. J. Bosco                                      NaN
# Policía Federal Argentina                                  NaN
# Quilmes                                                  252.0
# River Plate                                                NaN
# Rosario                                                 5089.0
# Río Cuarto                                                 NaN
# Río Negro                                                760.0
# Salta                                                      NaN
# Salvador                                                 374.0
# San Andrés                                                 NaN
# San Andés                                                  NaN
# San Isidro                                                 NaN
# San Juan                                                1729.0
# San Luis                                                   NaN
# San Martín                                                 NaN
# San Pablo  T                                               NaN
# San Pablo T                                              143.0
# Santiago del Estero                                        NaN
# Seguridad Marítima                                         NaN
# Sur                                                        NaN
# Tecnológica Nacional                                      78.0
# Tierra del Fuego                                           NaN
# Torcuato Di Tella                                        174.0
# Tres de Febrero                                            NaN
# Tucumán                                                 4477.0
# Villa María                                              237.0
# Villa Mercedes                                             NaN
#
#                                   (Arquitectura y Diseño, NI)  \
# Abierta Interamericana                                  238.0
# Aconcagua                                                10.0
# Adventista del Plata                                      NaN
# Aeronáutico                                               NaN
# Argentina John F. Kennedy                                35.0
# Argentina de la Empresa                                 646.0
# Arturo Jauretche                                          NaN
# Atlántida Argentina                                       NaN
# Austral                                                   NaN
# Autónoma de Entre Ríos                                    NaN
# Avellaneda                                               15.0
# Belgrano                                                421.0
# Blas Pascal                                              96.0
# Buenos Aires                                           6584.0
# CAECE                                                    32.0
# CEMA                                                      NaN
# CEMIC                                                     NaN
# Catamarca                                                 NaN
# Católica Argentina                                        NaN
# Católica de Cuyo                                          NaN
# Católica de Córdoba                                      90.0
# Católica de La Plata                                    115.0
# Católica de Salta                                       270.0
# Católica de Santa Fe                                    158.0
# Católica de Santiago del Estero                          71.0
# Centro Educativo Latinoamericano                          NaN
# Centro de la PBA                                          NaN
# Chaco Austral                                             NaN
# Champagnat                                               34.0
# Chilecito                                                 NaN
# ...                                                       ...
# Oeste                                                     NaN
# Palermo                                                1523.0
# Patagonia Austral                                         NaN
# Patagonia S. J. Bosco                                     NaN
# Policía Federal Argentina                                 NaN
# Quilmes                                                  72.0
# River Plate                                               NaN
# Rosario                                                 764.0
# Río Cuarto                                                NaN
# Río Negro                                               396.0
# Salta                                                     NaN
# Salvador                                                121.0
# San Andrés                                                NaN
# San Andés                                                 NaN
# San Isidro                                                NaN
# San Juan                                                310.0
# San Luis                                                  NaN
# San Martín                                                NaN
# San Pablo  T                                              NaN
# San Pablo T                                              33.0
# Santiago del Estero                                       NaN
# Seguridad Marítima                                        NaN
# Sur                                                       NaN
# Tecnológica Nacional                                     27.0
# Tierra del Fuego                                          NaN
# Torcuato Di Tella                                        44.0
# Tres de Febrero                                           NaN
# Tucumán                                                 702.0
# Villa María                                              78.0
# Villa Mercedes                                            NaN
#
#                                   (Arquitectura y Diseño, RE)  \
# Abierta Interamericana                                  818.0
# Aconcagua                                                39.0
# Adventista del Plata                                      NaN
# Aeronáutico                                               NaN
# Argentina John F. Kennedy                               268.0
# Argentina de la Empresa                                1366.0
# Arturo Jauretche                                          NaN
# Atlántida Argentina                                       NaN
# Austral                                                   NaN
# Autónoma de Entre Ríos                                    NaN
# Avellaneda                                               68.0
# Belgrano                                               1539.0
# Blas Pascal                                             342.0
# Buenos Aires                                          36406.0
# CAECE                                                   158.0
# CEMA                                                      NaN
# CEMIC                                                     NaN
# Catamarca                                                 NaN
# Católica Argentina                                        NaN
# Católica de Cuyo                                          NaN
# Católica de Córdoba                                     444.0
# Católica de La Plata                                    387.0
# Católica de Salta                                       742.0
# Católica de Santa Fe                                    730.0
# Católica de Santiago del Estero                          26.0
# Centro Educativo Latinoamericano                          NaN
# Centro de la PBA                                          NaN
# Chaco Austral                                             NaN
# Champagnat                                               98.0
# Chilecito                                                 NaN
# ...                                                       ...
# Oeste                                                     NaN
# Palermo                                                3599.0
# Patagonia Austral                                         NaN
# Patagonia S. J. Bosco                                     NaN
# Policía Federal Argentina                                 NaN
# Quilmes                                                 180.0
# River Plate                                               NaN
# Rosario                                                4325.0
# Río Cuarto                                                NaN
# Río Negro                                               364.0
# Salta                                                     NaN
# Salvador                                                253.0
# San Andrés                                                NaN
# San Andés                                                 NaN
# San Isidro                                                NaN
# San Juan                                               1419.0
# San Luis                                                  NaN
# San Martín                                                NaN
# San Pablo  T                                              NaN
# San Pablo T                                             110.0
# Santiago del Estero                                       NaN
# Seguridad Marítima                                        NaN
# Sur                                                       NaN
# Tecnológica Nacional                                     51.0
# Tierra del Fuego                                          NaN
# Torcuato Di Tella                                       130.0
# Tres de Febrero                                           NaN
# Tucumán                                                3775.0
# Villa María                                             159.0
# Villa Mercedes                                            NaN
#
#                                   (Astronomía, EGRE)  (Astronomía, EST)  \
# Abierta Interamericana                           NaN                NaN
# Aconcagua                                        NaN                NaN
# Adventista del Plata                             NaN                NaN
# Aeronáutico                                      NaN                NaN
# Argentina John F. Kennedy                      124.0             1237.0
# Argentina de la Empresa                          NaN                NaN
# Arturo Jauretche                                 NaN                NaN
# Atlántida Argentina                              NaN                NaN
# Austral                                          NaN                NaN
# Autónoma de Entre Ríos                           NaN                NaN
# Avellaneda                                       NaN                NaN
# Belgrano                                         0.0               10.0
# Blas Pascal                                      NaN                NaN
# Buenos Aires                                     NaN                NaN
# CAECE                                            NaN                NaN
# CEMA                                             NaN                NaN
# CEMIC                                            NaN                NaN
# Catamarca                                        NaN                NaN
# Católica Argentina                               NaN                NaN
# Católica de Cuyo                                42.0              380.0
# Católica de Córdoba                             42.0              398.0
# Católica de La Plata                             NaN                NaN
# Católica de Salta                                NaN                NaN
# Católica de Santa Fe                             NaN                NaN
# Católica de Santiago del Estero                  NaN                NaN
# Centro Educativo Latinoamericano                 NaN                NaN
# Centro de la PBA                                 NaN                NaN
# Chaco Austral                                    NaN                NaN
# Champagnat                                       NaN                NaN
# Chilecito                                        NaN                NaN
# ...                                              ...                ...
# Oeste                                            NaN                NaN
# Palermo                                          NaN                NaN
# Patagonia Austral                                NaN                NaN
# Patagonia S. J. Bosco                            NaN                NaN
# Policía Federal Argentina                        NaN                NaN
# Quilmes                                          NaN                NaN
# River Plate                                      NaN                NaN
# Rosario                                          NaN                NaN
# Río Cuarto                                       NaN                NaN
# Río Negro                                        NaN                NaN
# Salta                                            NaN                NaN
# Salvador                                         NaN                NaN
# San Andrés                                       NaN                NaN
# San Andés                                        NaN                NaN
# San Isidro                                       NaN                NaN
# San Juan                                         3.0               72.0
# San Luis                                         NaN                NaN
# San Martín                                       NaN                NaN
# San Pablo  T                                     NaN                NaN
# San Pablo T                                      NaN                NaN
# Santiago del Estero                              NaN                NaN
# Seguridad Marítima                               NaN                NaN
# Sur                                              NaN                NaN
# Tecnológica Nacional                             NaN                NaN
# Tierra del Fuego                                 NaN                NaN
# Torcuato Di Tella                                NaN                NaN
# Tres de Febrero                                  NaN                NaN
# Tucumán                                          NaN                NaN
# Villa María                                      NaN                NaN
# Villa Mercedes                                   NaN                NaN
#
#                                   (Astronomía, NI)  (Astronomía, RE)  \
# Abierta Interamericana                         NaN               NaN
# Aconcagua                                      NaN               NaN
# Adventista del Plata                           NaN               NaN
# Aeronáutico                                    NaN               NaN
# Argentina John F. Kennedy                    170.0            1067.0
# Argentina de la Empresa                        NaN               NaN
# Arturo Jauretche                               NaN               NaN
# Atlántida Argentina                            NaN               NaN
# Austral                                        NaN               NaN
# Autónoma de Entre Ríos                         NaN               NaN
# Avellaneda                                     NaN               NaN
# Belgrano                                       0.0              10.0
# Blas Pascal                                    NaN               NaN
# Buenos Aires                                   NaN               NaN
# CAECE                                          NaN               NaN
# CEMA                                           NaN               NaN
# CEMIC                                          NaN               NaN
# Catamarca                                      NaN               NaN
# Católica Argentina                             NaN               NaN
# Católica de Cuyo                              51.0             329.0
# Católica de Córdoba                           57.0             341.0
# Católica de La Plata                           NaN               NaN
# Católica de Salta                              NaN               NaN
# Católica de Santa Fe                           NaN               NaN
# Católica de Santiago del Estero                NaN               NaN
# Centro Educativo Latinoamericano               NaN               NaN
# Centro de la PBA                               NaN               NaN
# Chaco Austral                                  NaN               NaN
# Champagnat                                     NaN               NaN
# Chilecito                                      NaN               NaN
# ...                                            ...               ...
# Oeste                                          NaN               NaN
# Palermo                                        NaN               NaN
# Patagonia Austral                              NaN               NaN
# Patagonia S. J. Bosco                          NaN               NaN
# Policía Federal Argentina                      NaN               NaN
# Quilmes                                        NaN               NaN
# River Plate                                    NaN               NaN
# Rosario                                        NaN               NaN
# Río Cuarto                                     NaN               NaN
# Río Negro                                      NaN               NaN
# Salta                                          NaN               NaN
# Salvador                                       NaN               NaN
# San Andrés                                     NaN               NaN
# San Andés                                      NaN               NaN
# San Isidro                                     NaN               NaN
# San Juan                                      10.0              62.0
# San Luis                                       NaN               NaN
# San Martín                                     NaN               NaN
# San Pablo  T                                   NaN               NaN
# San Pablo T                                    NaN               NaN
# Santiago del Estero                            NaN               NaN
# Seguridad Marítima                             NaN               NaN
# Sur                                            NaN               NaN
# Tecnológica Nacional                           NaN               NaN
# Tierra del Fuego                               NaN               NaN
# Torcuato Di Tella                              NaN               NaN
# Tres de Febrero                                NaN               NaN
# Tucumán                                        NaN               NaN
# Villa María                                    NaN               NaN
# Villa Mercedes                                 NaN               NaN
#
#                                   (Biología, EGRE)  (Biología, EST)  \
# Abierta Interamericana                         NaN              NaN
# Aconcagua                                      NaN              NaN
# Adventista del Plata                           NaN              NaN
# Aeronáutico                                    NaN              NaN
# Argentina John F. Kennedy                      NaN              NaN
# Argentina de la Empresa                        0.0             39.0
# Arturo Jauretche                               NaN            207.0
# Atlántida Argentina                            NaN              NaN
# Austral                                        NaN              NaN
# Autónoma de Entre Ríos                        15.0            485.0
# Avellaneda                                     0.0            298.0
# Belgrano                                       5.0             54.0
# Blas Pascal                                   20.0            482.0
# Buenos Aires                                 181.0           5202.0
# CAECE                                         26.0            357.0
# CEMA                                           NaN              NaN
# CEMIC                                          NaN              NaN
# Catamarca                                     55.0           1372.0
# Católica Argentina                            22.0            432.0
# Católica de Cuyo                               NaN              NaN
# Católica de Córdoba                            NaN              NaN
# Católica de La Plata                           NaN              NaN
# Católica de Salta                              6.0             12.0
# Católica de Santa Fe                           5.0             81.0
# Católica de Santiago del Estero                NaN              NaN
# Centro Educativo Latinoamericano               NaN              NaN
# Centro de la PBA                              14.0            478.0
# Chaco Austral                                  NaN              NaN
# Champagnat                                     2.0             11.0
# Chilecito                                      1.0            182.0
# ...                                            ...              ...
# Oeste                                          NaN              NaN
# Palermo                                        NaN              NaN
# Patagonia Austral                              2.0            155.0
# Patagonia S. J. Bosco                         49.0           1219.0
# Policía Federal Argentina                      NaN              NaN
# Quilmes                                        NaN              NaN
# River Plate                                    NaN              NaN
# Rosario                                        0.0            138.0
# Río Cuarto                                    44.0            528.0
# Río Negro                                      6.0            430.0
# Salta                                         54.0           1802.0
# Salvador                                      24.0            261.0
# San Andrés                                     NaN              NaN
# San Andés                                      NaN              NaN
# San Isidro                                     NaN              NaN
# San Juan                                      32.0            354.0
# San Luis                                      38.0            516.0
# San Martín                                     1.0            223.0
# San Pablo  T                                   NaN              NaN
# San Pablo T                                    NaN              NaN
# Santiago del Estero                            5.0            157.0
# Seguridad Marítima                             NaN              NaN
# Sur                                           36.0            930.0
# Tecnológica Nacional                         347.0            633.0
# Tierra del Fuego                               NaN             66.0
# Torcuato Di Tella                              NaN              NaN
# Tres de Febrero                                5.0            258.0
# Tucumán                                       35.0           1064.0
# Villa María                                    0.0            114.0
# Villa Mercedes                                 NaN             37.0
#
#                                   (Biología, NI)  (Biología, RE)  \
# Abierta Interamericana                       NaN             NaN
# Aconcagua                                    NaN             NaN
# Adventista del Plata                         NaN             NaN
# Aeronáutico                                  NaN             NaN
# Argentina John F. Kennedy                    NaN             NaN
# Argentina de la Empresa                     17.0            22.0
# Arturo Jauretche                            94.0           113.0
# Atlántida Argentina                          NaN             NaN
# Austral                                      NaN             NaN
# Autónoma de Entre Ríos                     154.0           331.0
# Avellaneda                                  28.0           270.0
# Belgrano                                     7.0            47.0
# Blas Pascal                                138.0           344.0
# Buenos Aires                               732.0          4470.0
# CAECE                                       66.0           291.0
# CEMA                                         NaN             NaN
# CEMIC                                        NaN             NaN
# Catamarca                                  369.0          1003.0
# Católica Argentina                         102.0           330.0
# Católica de Cuyo                             NaN             NaN
# Católica de Córdoba                          NaN             NaN
# Católica de La Plata                         NaN             NaN
# Católica de Salta                            0.0            12.0
# Católica de Santa Fe                         7.0            74.0
# Católica de Santiago del Estero              NaN             NaN
# Centro Educativo Latinoamericano             NaN             NaN
# Centro de la PBA                           114.0           364.0
# Chaco Austral                                NaN             NaN
# Champagnat                                   0.0            11.0
# Chilecito                                   32.0           150.0
# ...                                          ...             ...
# Oeste                                        NaN             NaN
# Palermo                                      NaN             NaN
# Patagonia Austral                           35.0           120.0
# Patagonia S. J. Bosco                      297.0           922.0
# Policía Federal Argentina                    NaN             NaN
# Quilmes                                      NaN             NaN
# River Plate                                  NaN             NaN
# Rosario                                     45.0            93.0
# Río Cuarto                                  99.0           429.0
# Río Negro                                  224.0           206.0
# Salta                                      351.0          1451.0
# Salvador                                    57.0           204.0
# San Andrés                                   NaN             NaN
# San Andés                                    NaN             NaN
# San Isidro                                   NaN             NaN
# San Juan                                    59.0           295.0
# San Luis                                    96.0           420.0
# San Martín                                  78.0           145.0
# San Pablo  T                                 NaN             NaN
# San Pablo T                                  NaN             NaN
# Santiago del Estero                         50.0           107.0
# Seguridad Marítima                           NaN             NaN
# Sur                                        315.0           615.0
# Tecnológica Nacional                         0.0           633.0
# Tierra del Fuego                            66.0             NaN
# Torcuato Di Tella                            NaN             NaN
# Tres de Febrero                             94.0           164.0
# Tucumán                                    328.0           736.0
# Villa María                                 86.0            28.0
# Villa Mercedes                              37.0             NaN
#
#                                   (Bioquímica y Farmacia, EGRE)  \
# Abierta Interamericana                                      NaN
# Aconcagua                                                   NaN
# Adventista del Plata                                        NaN
# Aeronáutico                                                 NaN
# Argentina John F. Kennedy                                   NaN
# Argentina de la Empresa                                     NaN
# Arturo Jauretche                                            NaN
# Atlántida Argentina                                         NaN
# Austral                                                     NaN
# Autónoma de Entre Ríos                                      NaN
# Avellaneda                                                  NaN
# Belgrano                                                   74.0
# Blas Pascal                                                 NaN
# Buenos Aires                                              376.0
# CAECE                                                       NaN
# CEMA                                                        NaN
# CEMIC                                                       NaN
# Catamarca                                                   NaN
# Católica Argentina                                         71.0
# Católica de Cuyo                                            NaN
# Católica de Córdoba                                        51.0
# Católica de La Plata                                        NaN
# Católica de Salta                                           7.0
# Católica de Santa Fe                                        NaN
# Católica de Santiago del Estero                             NaN
# Centro Educativo Latinoamericano                            NaN
# Centro de la PBA                                            NaN
# Chaco Austral                                               6.0
# Champagnat                                                  NaN
# Chilecito                                                   NaN
# ...                                                         ...
# Oeste                                                       NaN
# Palermo                                                     NaN
# Patagonia Austral                                           NaN
# Patagonia S. J. Bosco                                       9.0
# Policía Federal Argentina                                   NaN
# Quilmes                                                     NaN
# River Plate                                                 NaN
# Rosario                                                    77.0
# Río Cuarto                                                  NaN
# Río Negro                                                   NaN
# Salta                                                       NaN
# Salvador                                                   23.0
# San Andrés                                                  NaN
# San Andés                                                   NaN
# San Isidro                                                  NaN
# San Juan                                                    NaN
# San Luis                                                   61.0
# San Martín                                                  NaN
# San Pablo  T                                                NaN
# San Pablo T                                                 NaN
# Santiago del Estero                                         NaN
# Seguridad Marítima                                          NaN
# Sur                                                       123.0
# Tecnológica Nacional                                        NaN
# Tierra del Fuego                                            NaN
# Torcuato Di Tella                                           NaN
# Tres de Febrero                                             NaN
# Tucumán                                                    60.0
# Villa María                                                 0.0
# Villa Mercedes                                              NaN
#
#                                   (Bioquímica y Farmacia, EST)  \
# Abierta Interamericana                                     NaN
# Aconcagua                                                  NaN
# Adventista del Plata                                       NaN
# Aeronáutico                                                NaN
# Argentina John F. Kennedy                                  NaN
# Argentina de la Empresa                                    NaN
# Arturo Jauretche                                         534.0
# Atlántida Argentina                                        NaN
# Austral                                                    NaN
# Autónoma de Entre Ríos                                     NaN
# Avellaneda                                                 NaN
# Belgrano                                                 974.0
# Blas Pascal                                                NaN
# Buenos Aires                                            8626.0
# CAECE                                                      NaN
# CEMA                                                       NaN
# CEMIC                                                      NaN
# Catamarca                                                  NaN
# Católica Argentina                                       470.0
# Católica de Cuyo                                           NaN
# Católica de Córdoba                                      367.0
# Católica de La Plata                                       NaN
# Católica de Salta                                        113.0
# Católica de Santa Fe                                       NaN
# Católica de Santiago del Estero                            NaN
# Centro Educativo Latinoamericano                           NaN
# Centro de la PBA                                           NaN
# Chaco Austral                                            661.0
# Champagnat                                                 NaN
# Chilecito                                                  NaN
# ...                                                        ...
# Oeste                                                      NaN
# Palermo                                                    NaN
# Patagonia Austral                                          NaN
# Patagonia S. J. Bosco                                    267.0
# Policía Federal Argentina                                  NaN
# Quilmes                                                    NaN
# River Plate                                                NaN
# Rosario                                                 2608.0
# Río Cuarto                                                 NaN
# Río Negro                                                  NaN
# Salta                                                      NaN
# Salvador                                                 431.0
# San Andrés                                                 NaN
# San Andés                                                  NaN
# San Isidro                                                 NaN
# San Juan                                                   NaN
# San Luis                                                1030.0
# San Martín                                                 NaN
# San Pablo  T                                               NaN
# San Pablo T                                                NaN
# Santiago del Estero                                        NaN
# Seguridad Marítima                                         NaN
# Sur                                                     1997.0
# Tecnológica Nacional                                       NaN
# Tierra del Fuego                                           NaN
# Torcuato Di Tella                                          NaN
# Tres de Febrero                                            NaN
# Tucumán                                                 1921.0
# Villa María                                               22.0
# Villa Mercedes                                             NaN
#
#                                   (Bioquímica y Farmacia, NI)  \
# Abierta Interamericana                                    NaN
# Aconcagua                                                 NaN
# Adventista del Plata                                      NaN
# Aeronáutico                                               NaN
# Argentina John F. Kennedy                                 NaN
# Argentina de la Empresa                                   NaN
# Arturo Jauretche                                        283.0
# Atlántida Argentina                                       NaN
# Austral                                                   NaN
# Autónoma de Entre Ríos                                    NaN
# Avellaneda                                                NaN
# Belgrano                                                375.0
# Blas Pascal                                               NaN
# Buenos Aires                                           1149.0
# CAECE                                                     NaN
# CEMA                                                      NaN
# CEMIC                                                     NaN
# Catamarca                                                 NaN
# Católica Argentina                                      124.0
# Católica de Cuyo                                          NaN
# Católica de Córdoba                                      59.0
# Católica de La Plata                                      NaN
# Católica de Salta                                        26.0
# Católica de Santa Fe                                      NaN
# Católica de Santiago del Estero                           NaN
# Centro Educativo Latinoamericano                          NaN
# Centro de la PBA                                          NaN
# Chaco Austral                                           200.0
# Champagnat                                                NaN
# Chilecito                                                 NaN
# ...                                                       ...
# Oeste                                                     NaN
# Palermo                                                   NaN
# Patagonia Austral                                         NaN
# Patagonia S. J. Bosco                                    68.0
# Policía Federal Argentina                                 NaN
# Quilmes                                                   NaN
# River Plate                                               NaN
# Rosario                                                 439.0
# Río Cuarto                                                NaN
# Río Negro                                                 NaN
# Salta                                                     NaN
# Salvador                                                 72.0
# San Andrés                                                NaN
# San Andés                                                 NaN
# San Isidro                                                NaN
# San Juan                                                  NaN
# San Luis                                                203.0
# San Martín                                                NaN
# San Pablo  T                                              NaN
# San Pablo T                                               NaN
# Santiago del Estero                                       NaN
# Seguridad Marítima                                        NaN
# Sur                                                     349.0
# Tecnológica Nacional                                      NaN
# Tierra del Fuego                                          NaN
# Torcuato Di Tella                                         NaN
# Tres de Febrero                                           NaN
# Tucumán                                                 217.0
# Villa María                                               8.0
# Villa Mercedes                                            NaN
#
#                                   (Bioquímica y Farmacia, RE)  \
# Abierta Interamericana                                    NaN
# Aconcagua                                                 NaN
# Adventista del Plata                                      NaN
# Aeronáutico                                               NaN
# Argentina John F. Kennedy                                 NaN
# Argentina de la Empresa                                   NaN
# Arturo Jauretche                                        251.0
# Atlántida Argentina                                       NaN
# Austral                                                   NaN
# ...
# San Juan                                                                     179.0
# San Luis                                                                      34.0
# San Martín                                                                   193.0
# San Pablo  T                                                                   NaN
# San Pablo T                                                                    NaN
# Santiago del Estero                                                          155.0
# Seguridad Marítima                                                             NaN
# Sur                                                                            NaN
# Tecnológica Nacional                                                           NaN
# Tierra del Fuego                                                              82.0
# Torcuato Di Tella                                                              NaN
# Tres de Febrero                                                                NaN
# Tucumán                                                                      533.0
# Villa María                                                                  180.0
# Villa Mercedes                                                                 NaN
#
#                                   (Sociología, Antropología y Servicio Social, RE)  \
# Abierta Interamericana                                                         NaN
# Aconcagua                                                                     86.0
# Adventista del Plata                                                          12.0
# Aeronáutico                                                                    NaN
# Argentina John F. Kennedy                                                     51.0
# Argentina de la Empresa                                                       16.0
# Arturo Jauretche                                                               NaN
# Atlántida Argentina                                                            NaN
# Austral                                                                      198.0
# Autónoma de Entre Ríos                                                       159.0
# Avellaneda                                                                    31.0
# Belgrano                                                                       NaN
# Blas Pascal                                                                    NaN
# Buenos Aires                                                                9669.0
# CAECE                                                                          1.0
# CEMA                                                                           NaN
# CEMIC                                                                          NaN
# Catamarca                                                                    385.0
# Católica Argentina                                                             NaN
# Católica de Cuyo                                                               NaN
# Católica de Córdoba                                                            2.0
# Católica de La Plata                                                          77.0
# Católica de Salta                                                            194.0
# Católica de Santa Fe                                                           NaN
# Católica de Santiago del Estero                                                NaN
# Centro Educativo Latinoamericano                                               NaN
# Centro de la PBA                                                             437.0
# Chaco Austral                                                                  NaN
# Champagnat                                                                     NaN
# Chilecito                                                                      NaN
# ...                                                                            ...
# Oeste                                                                          NaN
# Palermo                                                                       36.0
# Patagonia Austral                                                            371.0
# Patagonia S. J. Bosco                                                        345.0
# Policía Federal Argentina                                                     62.0
# Quilmes                                                                     1028.0
# River Plate                                                                    NaN
# Rosario                                                                     1539.0
# Río Cuarto                                                                     NaN
# Río Negro                                                                    146.0
# Salta                                                                        223.0
# Salvador                                                                     168.0
# San Andrés                                                                     NaN
# San Andés                                                                      NaN
# San Isidro                                                                     NaN
# San Juan                                                                     903.0
# San Luis                                                                     172.0
# San Martín                                                                   484.0
# San Pablo  T                                                                   NaN
# San Pablo T                                                                    NaN
# Santiago del Estero                                                          645.0
# Seguridad Marítima                                                             NaN
# Sur                                                                            NaN
# Tecnológica Nacional                                                           NaN
# Tierra del Fuego                                                               NaN
# Torcuato Di Tella                                                              NaN
# Tres de Febrero                                                                NaN
# Tucumán                                                                     1316.0
# Villa María                                                                  349.0
# Villa Mercedes                                                                 NaN
#
#                                   (Veterinaria, EGRE)  (Veterinaria, EST)  \
# Abierta Interamericana                            NaN                 NaN
# Aconcagua                                         NaN                 NaN
# Adventista del Plata                              NaN                 NaN
# Aeronáutico                                       NaN                 NaN
# Argentina John F. Kennedy                         NaN                 NaN
# Argentina de la Empresa                           NaN                 NaN
# Arturo Jauretche                                  NaN                 NaN
# Atlántida Argentina                               NaN                 NaN
# Austral                                           NaN                 NaN
# Autónoma de Entre Ríos                            NaN                 NaN
# Avellaneda                                        NaN                 NaN
# Belgrano                                          NaN                 NaN
# Blas Pascal                                       NaN                 NaN
# Buenos Aires                                    233.0              6516.0
# CAECE                                             NaN                 NaN
# CEMA                                              NaN                 NaN
# CEMIC                                             NaN                 NaN
# Catamarca                                         NaN                 NaN
# Católica Argentina                                NaN                 NaN
# Católica de Cuyo                                  0.0               110.0
# Católica de Córdoba                              54.0               619.0
# Católica de La Plata                              NaN                 NaN
# Católica de Salta                                16.0               473.0
# Católica de Santa Fe                              NaN                 NaN
# Católica de Santiago del Estero                   NaN                 NaN
# Centro Educativo Latinoamericano                  NaN                 NaN
# Centro de la PBA                                 97.0              1471.0
# Chaco Austral                                     NaN                 NaN
# Champagnat                                        NaN                 NaN
# Chilecito                                         NaN                 NaN
# ...                                               ...                 ...
# Oeste                                             NaN                 NaN
# Palermo                                           NaN                 NaN
# Patagonia Austral                                 NaN                 NaN
# Patagonia S. J. Bosco                             NaN                 NaN
# Policía Federal Argentina                         NaN                 NaN
# Quilmes                                           NaN                 NaN
# River Plate                                       NaN                 NaN
# Rosario                                          54.0              1592.0
# Río Cuarto                                      145.0              2120.0
# Río Negro                                         0.0               145.0
# Salta                                             NaN                 NaN
# Salvador                                         34.0               630.0
# San Andrés                                        NaN                 NaN
# San Andés                                         NaN                 NaN
# San Isidro                                        NaN                 NaN
# San Juan                                          NaN                 NaN
# San Luis                                          2.0                13.0
# San Martín                                        NaN                 NaN
# San Pablo  T                                      NaN                 NaN
# San Pablo T                                       NaN                 NaN
# Santiago del Estero                               NaN                 NaN
# Seguridad Marítima                                NaN                 NaN
# Sur                                               NaN                 NaN
# Tecnológica Nacional                              NaN                 NaN
# Tierra del Fuego                                  NaN                 NaN
# Torcuato Di Tella                                 NaN                 NaN
# Tres de Febrero                                   NaN                 NaN
# Tucumán                                          26.0               801.0
# Villa María                                       2.0               416.0
# Villa Mercedes                                    NaN                 NaN
#
#                                   (Veterinaria, NI)  (Veterinaria, RE)
# Abierta Interamericana                          NaN                NaN
# Aconcagua                                       NaN                NaN
# Adventista del Plata                            NaN                NaN
# Aeronáutico                                     NaN                NaN
# Argentina John F. Kennedy                       NaN                NaN
# Argentina de la Empresa                         NaN                NaN
# Arturo Jauretche                                NaN                NaN
# Atlántida Argentina                             NaN                NaN
# Austral                                         NaN                NaN
# Autónoma de Entre Ríos                          NaN                NaN
# Avellaneda                                      NaN                NaN
# Belgrano                                        NaN                NaN
# Blas Pascal                                     NaN                NaN
# Buenos Aires                                 1103.0             5413.0
# CAECE                                           NaN                NaN
# CEMA                                            NaN                NaN
# CEMIC                                           NaN                NaN
# Catamarca                                       NaN                NaN
# Católica Argentina                              NaN                NaN
# Católica de Cuyo                               35.0               75.0
# Católica de Córdoba                            93.0              526.0
# Católica de La Plata                            NaN                NaN
# Católica de Salta                             124.0              349.0
# Católica de Santa Fe                            NaN                NaN
# Católica de Santiago del Estero                 NaN                NaN
# Centro Educativo Latinoamericano                NaN                NaN
# Centro de la PBA                              218.0             1253.0
# Chaco Austral                                   NaN                NaN
# Champagnat                                      NaN                NaN
# Chilecito                                       NaN                NaN
# ...                                             ...                ...
# Oeste                                           NaN                NaN
# Palermo                                         NaN                NaN
# Patagonia Austral                               NaN                NaN
# Patagonia S. J. Bosco                           NaN                NaN
# Policía Federal Argentina                       NaN                NaN
# Quilmes                                         NaN                NaN
# River Plate                                     NaN                NaN
# Rosario                                       266.0             1326.0
# Río Cuarto                                    285.0             1835.0
# Río Negro                                      54.0               91.0
# Salta                                           NaN                NaN
# Salvador                                      156.0              474.0
# San Andrés                                      NaN                NaN
# San Andés                                       NaN                NaN
# San Isidro                                      NaN                NaN
# San Juan                                        NaN                NaN
# San Luis                                        0.0               13.0
# San Martín                                      NaN                NaN
# San Pablo  T                                    NaN                NaN
# San Pablo T                                     NaN                NaN
# Santiago del Estero                             NaN                NaN
# Seguridad Marítima                              NaN                NaN
# Sur                                             NaN                NaN
# Tecnológica Nacional                            NaN                NaN
# Tierra del Fuego                                NaN                NaN
# Torcuato Di Tella                               NaN                NaN
# Tres de Febrero                                 NaN                NaN
# Tucumán                                       145.0              656.0
# Villa María                                   130.0              286.0
# Villa Mercedes                                  NaN                NaN
#
# [119 rows x 125 columns]

# %%
df = pd.concat([ests_disc.loc[ests_disc.index.isin(inst_CABA['Institución'])].sum(),
          ests_disc.loc[ests_disc.index.isin(inst_GBA['Institución'])].sum(),
          ests_disc.loc[ests_disc.index.isin(inst_PBA['Institución'])].sum()], axis = 1)
df.columns = ['CABA', 'GBA', 'PBA']
ests = df.loc[df.index.get_level_values(1) == 'EST']

# %%
from numpy import round
round(100*ests.sort_values(by = 'CABA', ascending = False)/ests.sum(), 2)
# Out:
#                                                                  CABA    GBA  \
#                                                    Institución
# Economía y Administración                          EST          21.31  25.09
# Arquitectura y Diseño                              EST          11.08   7.00
# Derecho                                            EST          10.38  13.90
# Ingeniería (2)                                     EST           9.38   4.61
# Medicina                                           EST           7.28   2.22
# Paramédicas y Auxiliares de la Medicina            EST           5.78   8.88
# Informática                                        EST           5.68   5.37
# Industrias                                         EST           4.20   3.71
# Relaciones Institucionales y Humanas               EST           3.04   3.39
# Ciencias de la Información y la Comunicación       EST           2.75   5.78
# Sociología, Antropología y Servicio Social         EST           2.38   4.81
# Bioquímica y Farmacia                              EST           2.11   1.45
# Ciencias del Suelo                                 EST           1.85   0.63
# Ciencias Agropecuarias                             EST           1.82   1.74
# Ciencias de la Información y de la Comunicación    EST           1.72   0.37
# Ciencias Políticas, Relaciones Internacionales ... EST           1.67   1.45
# Biología                                           EST           1.44   1.91
# Veterinaria                                        EST           1.43   1.20
# Odontología                                        EST           1.10   1.40
# Demografía y Geografía                             EST           0.87   2.27
# Otras Ciencias Sociales                            EST           0.64   0.53
# Matemática                                         EST           0.40   0.49
# Estadística                                        EST           0.36   0.25
# Química                                            EST           0.35   0.50
# Física                                             EST           0.34   0.24
# Astronomía                                         EST           0.32   0.52
# Ingeniería                                         EST           0.14   0.00
# Meteorología                                       EST           0.08   0.04
# Otras Ciencias Aplicadas                           EST           0.06   0.26
# Salud Pública                                      EST           0.02   0.00
# Sanidad                                            EST           0.01   0.00
#
#                                                                   PBA
#                                                    Institución
# Economía y Administración                          EST          32.04
# Arquitectura y Diseño                              EST           4.91
# Derecho                                            EST          10.18
# Ingeniería (2)                                     EST           5.50
# Medicina                                           EST           1.30
# Paramédicas y Auxiliares de la Medicina            EST           4.96
# Informática                                        EST           4.50
# Industrias                                         EST           5.20
# Relaciones Institucionales y Humanas               EST           0.14
# Ciencias de la Información y la Comunicación       EST           1.46
# Sociología, Antropología y Servicio Social         EST           5.57
# Bioquímica y Farmacia                              EST           3.21
# Ciencias del Suelo                                 EST           1.00
# Ciencias Agropecuarias                             EST           7.46
# Ciencias de la Información y de la Comunicación    EST           0.23
# Ciencias Políticas, Relaciones Internacionales ... EST           0.46
# Biología                                           EST           3.98
# Veterinaria                                        EST           1.97
# Odontología                                        EST           0.00
# Demografía y Geografía                             EST           3.79
# Otras Ciencias Sociales                            EST           0.17
# Matemática                                         EST           0.91
# Estadística                                        EST           0.00
# Química                                            EST           0.62
# Física                                             EST           0.34
# Astronomía                                         EST           0.00
# Ingeniería                                         EST           0.00
# Meteorología                                       EST           0.00
# Otras Ciencias Aplicadas                           EST           0.10
# Salud Pública                                      EST           0.00
# Sanidad                                            EST           0.00

# %%
egre = df.loc[df.index.get_level_values(1) == 'EGRE'].fillna(0).astype(int)

egre.sort_values(by = 'CABA')
# Out:
#                                                                 CABA   GBA  \
#                                                    Institución
# Odontología                                        EGRE            0     0
# Meteorología                                       EGRE           10     0
# Salud Pública                                      EGRE           20     0
# Sanidad                                            EGRE           32     0
# Otras Ciencias Aplicadas                           EGRE           47     4
# Matemática                                         EGRE           49    37
# Física                                             EGRE           49    14
# Ingeniería                                         EGRE           59     0
# Estadística                                        EGRE          114    20
# Astronomía                                         EGRE          139    61
# Química                                            EGRE          260   193
# Veterinaria                                        EGRE          267   140
# Ciencias de la Información y la Comunicación       EGRE          267   790
# Otras Ciencias Sociales                            EGRE          298    47
# Demografía y Geografía                             EGRE          364   307
# Sociología, Antropología y Servicio Social         EGRE          478   444
# Bioquímica y Farmacia                              EGRE          544   141
# Biología                                           EGRE          628   141
# Ciencias del Suelo                                 EGRE          709   106
# Ciencias Agropecuarias                             EGRE          715   360
# Ciencias Políticas, Relaciones Internacionales ... EGRE          765   146
# Ciencias de la Información y de la Comunicación    EGRE          878   115
# Informática                                        EGRE         1188   474
# Relaciones Institucionales y Humanas               EGRE         1235   569
# Industrias                                         EGRE         1714   501
# Ingeniería (2)                                     EGRE         1820   297
# Medicina                                           EGRE         2049   347
# Arquitectura y Diseño                              EGRE         2879   787
# Paramédicas y Auxiliares de la Medicina            EGRE         4351  1748
# Derecho                                            EGRE         5772  2889
# Economía y Administración                          EGRE         8627  3061
#
#                                                                  PBA
#                                                    Institución
# Odontología                                        EGRE            0
# Meteorología                                       EGRE            0
# Salud Pública                                      EGRE            0
# Sanidad                                            EGRE            0
# Otras Ciencias Aplicadas                           EGRE            0
# Matemática                                         EGRE           23
# Física                                             EGRE            7
# Ingeniería                                         EGRE            0
# Estadística                                        EGRE            0
# Astronomía                                         EGRE            0
# Química                                            EGRE           15
# Veterinaria                                        EGRE           97
# Ciencias de la Información y la Comunicación       EGRE           47
# Otras Ciencias Sociales                            EGRE            1
# Demografía y Geografía                             EGRE          129
# Sociología, Antropología y Servicio Social         EGRE          266
# Bioquímica y Farmacia                              EGRE          131
# Biología                                           EGRE          122
# Ciencias del Suelo                                 EGRE           63
# Ciencias Agropecuarias                             EGRE          257
# Ciencias Políticas, Relaciones Internacionales ... EGRE           13
# Ciencias de la Información y de la Comunicación    EGRE           14
# Informática                                        EGRE          193
# Relaciones Institucionales y Humanas               EGRE           23
# Industrias                                         EGRE          208
# Ingeniería (2)                                     EGRE          268
# Medicina                                           EGRE           71
# Arquitectura y Diseño                              EGRE          172
# Paramédicas y Auxiliares de la Medicina            EGRE          180
# Derecho                                            EGRE          513
# Economía y Administración                          EGRE         1256
