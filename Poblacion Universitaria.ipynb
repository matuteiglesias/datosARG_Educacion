# %%
import pandas as pd
# import seaborn as sns
import numpy as np

# cm = sns.light_palette("green", as_cmap=True)
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_fwf('./anuario_2013_c2115part.txt', )
# Out:
#                          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        Total_de_las_instituciones    246.052     71.748      8.239
# 1    Total_Universidades_Nacionales    240.445     69.990      8.239
# 2                  Arturo_Jauretche          -          -          -
# 3                        Avellaneda          -          -          -
# 4                      Buenos_Aires          -          -          -
# 5                         Catamarca          -          -          -
# 6                  Centro_de_la_PBA          -          -          -
# 7                     Chaco_Austral          -          -          -
# 8                         Chilecito      3.308        755        182
# 9                           Comahue          -          -          -
# 10                          Córdoba    108.373     21.884      3.458
# 11                             Cuyo     31.451      6.660        493
# 12                       Entre_Ríos          -          -          -
# ...
