# %%
import pandas as pd
pd.options.display.max_columns = 99
import numpy as np

# %%
df = pd.read_csv('./cuadro_1.1.20.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_1.2.1.a.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_1.2.1.b.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_2.1.1.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_2.1.2.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_2.1.3.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_2.1.4.a.csv', header = [0, 1], index_col=0, thousands='.')
df = pd.read_csv('./cuadro_2.1.5.csv', header = [0, 1], index_col=0, thousands='.')
# df = pd.read_csv('./cuadro_2.1.3.csv', header = [0, 1], index_col=0, thousands='.')
df
# Out:
#                                 Unnamed: 1_level_0 Grupos de edad           \
# Institución                                  Total            <19     2024
# Total de las instituciones                  315593       119447.0  99794.0
# Total Universidades Nacionales              301841       116845.0  95647.0
# Arturo Jauretche                              3982          736.0   1236.0
# Avellaneda                                    1957          108.0    357.0
# Buenos Aires                                 51697        28816.0  14668.0
# Catamarca                                     2821         1155.0    860.0
# Centro de la PBA                              2666         1133.0    750.0
# Chaco Austral                                 1098          445.0    411.0
# Chilecito                                      595          150.0    145.0
# Comahue                                       8911         2520.0   3258.0
# ...
